# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.loc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads = recent_grads.dropna()

# %%
recent_grads.plot("Sample_size","Median",kind="scatter",title="median earnings vs. sample size")

# %%
recent_grads.plot("Sample_size","Unemployment_rate",kind="scatter",title="sample size vs. unemployment",xlim=(0,3000))

# %%
recent_grads.plot("Full_time","Median",kind="scatter",title="Median earnings vs. number of full-time professionals")

# %%
recent_grads.plot("ShareWomen","Unemployment_rate",kind="scatter",title="Unemployment rates vs. female shares of majors")

# %%
recent_grads.plot("Men","Median",kind="scatter",title="Median earnings vs. number of male graduates")

# %%
recent_grads.plot("Women","Median",kind="scatter",title="Median earnings vs. number of female graduates")

# %% [markdown]
# ## Findings
#
# There's not much correlation between popularity and median earnings, women share and unemployment rates, women share and median earnings.

# %%
recent_grads["Sample_size"].hist(bins=10,range=(0,5000))

# %%
recent_grads["Median"].hist(bins=20)

# %%
recent_grads["Employed"].plot(kind="hist")

# %%
recent_grads["Full_time"].plot(kind="hist")

# %%
recent_grads["ShareWomen"].hist(range=(0,1))

# %%
recent_grads["Unemployment_rate"].plot(kind="hist")

# %%
recent_grads["Men"].hist()

# %%
recent_grads["Women"].hist(bins=25)

# %% [markdown]
# ## Findings
#
# Based on "Median" histogram Most common median salary is between $30000 - $$35000
#
# Based on "ShareWomen" histogram around 60% of the majors are predominantly female.

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size","Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb11828a160>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb0bf42b9e8>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]],figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb0bf362048>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb0bf12def0>]], dtype=object)

# %%
first_10 = recent_grads.head(10)
last_10 = recent_grads.tail(10)

first_10.plot.bar("Major","ShareWomen")
last_10.plot.bar("Major","ShareWomen")

# %%
first_10.plot.bar("Major","Unemployment_rate")
last_10.plot.bar("Major","Unemployment_rate")
